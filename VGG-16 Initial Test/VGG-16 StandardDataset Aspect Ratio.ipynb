# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from google.colab import drive


import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import random

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from google.colab import drive

from sklearn.metrics import classification_report, log_loss, accuracy_score
from sklearn.model_selection import train_test_split

# %%
drive.mount('/content/gdrive', force_remount=True)
# %cd /content/gdrive/My Drive/

data_dir = '/content/gdrive/My Drive/Waste Dataset - Pre-processing (image resizing 100x100 (Aspect Ratio))/'


#/////////////////////////////////////////////////////////////////////

Name=[]
for file in os.listdir(data_dir):
    Name+=[file]
    
print(Name)
print(len(Name))

#/////////////////////////////////////////////////////////////////////
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# ['Waste 1 - Clear Bottle', 'Waste 2 - Coloured Bottle', 'Waste 3 - Clear Plastic Bag', 'Waste 4 - Coloured Plastic Bag']
# 4

# %%
dataset=[]
count=0
for file in os.listdir(data_dir):
    path=os.path.join(data_dir,file)
    for im in os.listdir(path):
        image=load_img(os.path.join(path,im))
        image=img_to_array(image)
        image=image/255.0
        dataset+=[[image,count]]
    count=count+1

n=len(dataset)
print(n)
# Out:
# 997

# %%
N=[]
for i in range(len(Name)):
    N+=[i]
    
normal_mapping=dict(zip(Name,N)) 
reverse_mapping=dict(zip(N,Name)) 

def mapper(value):
    return reverse_mapping[value]

    #///////////////////////////////////////////////////////

num=[]
for i in range(n):
    num+=[i]
random.shuffle(num)
print(num[0:5])

#//////////////////////////////////////////////////////////
data,labels=zip(*dataset)
data=np.array(data)
labels=np.array(labels)

train=data[num[0:(n//10)*8]]
trainlabel=labels[num[0:(n//10)*8]]

test=data[num[(n//10)*8:]]
testlabel=labels[num[(n//10)*8:]]


#////////////////////////////////////////////////////////////
trainlabel2=to_categorical(trainlabel)

trainx,testx,trainy,testy=train_test_split(train,trainlabel2,test_size=0.2,random_state=44)

#////////////////////////////////////////////////////////////////
print(trainx.shape)
print(testx.shape)
print(trainy.shape)
print(testy.shape)
# Out:
# [298, 902, 473, 60, 548]
# (633, 100, 100, 3)
# (159, 100, 100, 3)
# (633, 4)
# (159, 4)

# %%
model = Sequential()
model.add(Conv2D(input_shape=(100,100,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

# %%
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4, activation="softmax"))

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 25, 25, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 12, 12, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              18878464
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 16388
# =================================================================
# Total params: 50,390,852
# Trainable params: 50,390,852
# Non-trainable params: 0
# _________________________________________________________________

# %%
# two training variables and two testing variables, trainx and trainy and testx and testy. How do i put them in here?
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq="epoch")
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=30, verbose=1, mode='auto')
hist = model.fit(trainx, trainy, batch_size=8, validation_data=(testx, testy), epochs=30,callbacks=[checkpoint,early])
# Out:
# Epoch 1/30
# 80/80 [==============================] - 323s 4s/step - loss: 1.5571 - accuracy: 0.2780 - val_loss: 1.3588 - val_accuracy: 0.3082
#
# Epoch 00001: val_accuracy improved from -inf to 0.30818, saving model to vgg16_1.h5
# Epoch 2/30
# 80/80 [==============================] - 306s 4s/step - loss: 1.3751 - accuracy: 0.2891 - val_loss: 1.3492 - val_accuracy: 0.3082
#
# Epoch 00002: val_accuracy did not improve from 0.30818
# Epoch 3/30
# 80/80 [==============================] - 298s 4s/step - loss: 1.3741 - accuracy: 0.2986 - val_loss: 1.3589 - val_accuracy: 0.3522
#
# Epoch 00003: val_accuracy improved from 0.30818 to 0.35220, saving model to vgg16_1.h5
# Epoch 4/30
# 80/80 [==============================] - 308s 4s/step - loss: 1.3734 - accuracy: 0.2875 - val_loss: 1.3530 - val_accuracy: 0.3522
#
# Epoch 00004: val_accuracy did not improve from 0.35220
# Epoch 5/30
# 80/80 [==============================] - 341s 4s/step - loss: 1.3728 - accuracy: 0.3017 - val_loss: 1.3461 - val_accuracy: 0.3082
#
# Epoch 00005: val_accuracy did not improve from 0.35220
# Epoch 6/30
# 80/80 [==============================] - 327s 4s/step - loss: 1.3734 - accuracy: 0.3002 - val_loss: 1.3517 - val_accuracy: 0.3082
#
# Epoch 00006: val_accuracy did not improve from 0.35220
# Epoch 7/30
# 80/80 [==============================] - 329s 4s/step - loss: 1.3722 - accuracy: 0.2907 - val_loss: 1.3466 - val_accuracy: 0.3082
#
# Epoch 00007: val_accuracy did not improve from 0.35220
# Epoch 8/30
# 80/80 [==============================] - 307s 4s/step - loss: 1.3727 - accuracy: 0.3002 - val_loss: 1.3461 - val_accuracy: 0.3082
#
# Epoch 00008: val_accuracy did not improve from 0.35220
# Epoch 9/30
# 80/80 [==============================] - 302s 4s/step - loss: 1.3723 - accuracy: 0.2796 - val_loss: 1.3515 - val_accuracy: 0.3082
#
# Epoch 00009: val_accuracy did not improve from 0.35220
# Epoch 10/30
# 80/80 [==============================] - 298s 4s/step - loss: 1.3717 - accuracy: 0.3002 - val_loss: 1.3464 - val_accuracy: 0.3082
#
# Epoch 00010: val_accuracy did not improve from 0.35220
# Epoch 11/30
# 80/80 [==============================] - 294s 4s/step - loss: 1.3721 - accuracy: 0.3002 - val_loss: 1.3502 - val_accuracy: 0.3082
#
# Epoch 00011: val_accuracy did not improve from 0.35220
# Epoch 12/30
# 80/80 [==============================] - 296s 4s/step - loss: 1.3721 - accuracy: 0.3002 - val_loss: 1.3482 - val_accuracy: 0.3082
#
# Epoch 00012: val_accuracy did not improve from 0.35220
# Epoch 13/30
# 80/80 [==============================] - 295s 4s/step - loss: 1.3722 - accuracy: 0.3002 - val_loss: 1.3456 - val_accuracy: 0.3082
#
# Epoch 00013: val_accuracy did not improve from 0.35220
# Epoch 14/30
# 80/80 [==============================] - 297s 4s/step - loss: 1.3717 - accuracy: 0.2907 - val_loss: 1.3449 - val_accuracy: 0.3082
#
# Epoch 00014: val_accuracy did not improve from 0.35220
# Epoch 15/30
# 80/80 [==============================] - 299s 4s/step - loss: 1.3718 - accuracy: 0.3002 - val_loss: 1.3490 - val_accuracy: 0.3082
#
# Epoch 00015: val_accuracy did not improve from 0.35220
# Epoch 16/30
# 80/80 [==============================] - 297s 4s/step - loss: 1.3713 - accuracy: 0.2938 - val_loss: 1.3486 - val_accuracy: 0.3082
#
# Epoch 00016: val_accuracy did not improve from 0.35220
# Epoch 17/30
# 80/80 [==============================] - 297s 4s/step - loss: 1.3718 - accuracy: 0.3002 - val_loss: 1.3482 - val_accuracy: 0.3082
#
# Epoch 00017: val_accuracy did not improve from 0.35220
# Epoch 18/30
# 80/80 [==============================] - 296s 4s/step - loss: 1.3718 - accuracy: 0.3002 - val_loss: 1.3494 - val_accuracy: 0.3082
#
# Epoch 00018: val_accuracy did not improve from 0.35220
# Epoch 19/30
# 80/80 [==============================] - 294s 4s/step - loss: 1.3725 - accuracy: 0.2923 - val_loss: 1.3449 - val_accuracy: 0.3522
#
# Epoch 00019: val_accuracy did not improve from 0.35220
# Epoch 20/30
# 80/80 [==============================] - 295s 4s/step - loss: 1.3726 - accuracy: 0.2923 - val_loss: 1.3470 - val_accuracy: 0.3082
#
# Epoch 00020: val_accuracy did not improve from 0.35220
# Epoch 21/30
# 80/80 [==============================] - 296s 4s/step - loss: 1.3715 - accuracy: 0.2970 - val_loss: 1.3449 - val_accuracy: 0.3082
#
# Epoch 00021: val_accuracy did not improve from 0.35220
# Epoch 22/30
# 80/80 [==============================] - 330s 4s/step - loss: 1.3718 - accuracy: 0.2859 - val_loss: 1.3476 - val_accuracy: 0.3082
#
# Epoch 00022: val_accuracy did not improve from 0.35220
# Epoch 23/30
# 80/80 [==============================] - 316s 4s/step - loss: 1.3724 - accuracy: 0.3002 - val_loss: 1.3493 - val_accuracy: 0.3082
#
# Epoch 00023: val_accuracy did not improve from 0.35220
# Epoch 24/30
# 80/80 [==============================] - 319s 4s/step - loss: 1.3716 - accuracy: 0.3002 - val_loss: 1.3480 - val_accuracy: 0.3082
#
# Epoch 00024: val_accuracy did not improve from 0.35220
# Epoch 25/30
# 80/80 [==============================] - 314s 4s/step - loss: 1.3718 - accuracy: 0.2765 - val_loss: 1.3457 - val_accuracy: 0.3082
#
# Epoch 00025: val_accuracy did not improve from 0.35220
# Epoch 26/30
# 80/80 [==============================] - 310s 4s/step - loss: 1.3720 - accuracy: 0.3002 - val_loss: 1.3475 - val_accuracy: 0.3082
#
# Epoch 00026: val_accuracy did not improve from 0.35220
# Epoch 27/30
# 80/80 [==============================] - 311s 4s/step - loss: 1.3720 - accuracy: 0.3002 - val_loss: 1.3458 - val_accuracy: 0.3082
#
# Epoch 00027: val_accuracy did not improve from 0.35220
# Epoch 28/30
# 80/80 [==============================] - 307s 4s/step - loss: 1.3725 - accuracy: 0.2844 - val_loss: 1.3458 - val_accuracy: 0.3082
#
# Epoch 00028: val_accuracy did not improve from 0.35220
# Epoch 29/30
# 80/80 [==============================] - 318s 4s/step - loss: 1.3710 - accuracy: 0.3002 - val_loss: 1.3462 - val_accuracy: 0.3082
#
# Epoch 00029: val_accuracy did not improve from 0.35220
# Epoch 30/30
# 80/80 [==============================] - 317s 4s/step - loss: 1.3711 - accuracy: 0.3002 - val_loss: 1.3461 - val_accuracy: 0.3082
#
# Epoch 00030: val_accuracy did not improve from 0.35220

# %%
y_pred=model.predict(testx)
pred=np.argmax(y_pred,axis=1)
ground = np.argmax(testy,axis=1)
print(classification_report(ground,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        56
#            1       0.31      1.00      0.47        49
#            2       0.00      0.00      0.00        29
#            3       0.00      0.00      0.00        25
#
#     accuracy                           0.31       159
#    macro avg       0.08      0.25      0.12       159
# weighted avg       0.09      0.31      0.15       159
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
get_acc = hist.history['accuracy']
value_acc = hist.history['val_accuracy']
get_loss = hist.history['loss']
validation_loss = hist.history['val_loss']

epochs = range(len(get_acc))
plt.plot(epochs, get_acc, 'r', label='Accuracy of Training data')
plt.plot(epochs, value_acc, 'b', label='Accuracy of Validation data')
plt.title('Training vs validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
epochs = range(len(get_loss))
plt.plot(epochs, get_loss, 'r', label='Loss of Training data')
plt.plot(epochs, validation_loss, 'b', label='Loss of Validation data')
plt.title('Training vs validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()
